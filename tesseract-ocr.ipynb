# %% [markdown]
# # Install and Import Modules

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from pytesseract) (11.0.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
import pytesseract
import time
from PIL import Image
import pandas as pd
import kagglehub
from typing import List
import string

path = kagglehub.dataset_download("trainingdatapro/ocr-receipts-text-detection")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
valid_data = [['BANANAS', 'FRAP'],
 ['R',
  'CARROTS',
  'SHREDDED',
  '10',
  'OZ',
  'R',
  'CUCUMBERS',
  'PERSIAN',
  '1',
  'LB',
  'TOMATOES',
  'CRUSHED',
  'NO',
  'SALT',
  'TOMATOES',
  'WHOLE',
  'NO',
  'SALT',
  'W',
  'BASIL',
  'ORGANIC',
  'OLD',
  'FASHIONED',
  'OATMEAL',
  'MINI',
  'PEARL',
  'TOMATOES',
  'PKG',
  'SHREDDED',
  'MOZZARELLA',
  'LITE',
  'T',
  'EGGS',
  '1',
  'DOZ',
  'ORGANIC',
  'BROWN',
  'BEANS',
  'GARBANZO',
  'SPROUTED',
  'CA',
  'STYLE',
  'A',
  'AVOCADOS',
  'HASS',
  'BAG',
  '4CT',
  'A',
  'APPLE',
  'BAG',
  'JAZZ',
  '2',
  'LB',
  'A',
  'PEPPER',
  'BELL',
  'EACH',
  'XL',
  'RED',
  'GROCERY',
  'NON',
  'TAXABLE',
  'BANANAS',
  'ORGANIC',
  'CREAMY',
  'SALTED',
  'PEANUT',
  'BUTTER',
  'WHL',
  'WHT',
  'PITA',
  'BREAD',
  'GROCERY',
  'NON',
  'TAXABLE'],
 ['GV', 'OATMEAL', 'OT', '200Z', 'TUM', 'M', 'ATHLETICS', 'DEXAS', '15X20'],
 ['TATER',
  'TOTS',
  'HARD',
  'PROV',
  'DC',
  'SNACK',
  'BARS',
  'HRI',
  'CL',
  'CHS',
  'HRI',
  'CL',
  'CHS',
  'HRI',
  'CL',
  'CHS',
  'HRI',
  '12',
  'U',
  'SG',
  'HRI',
  'CL',
  'PEP',
  'EARBUDS',
  'SC',
  'BCN',
  'CHDDR',
  'ABF',
  'THINBRST',
  'ABF',
  'THINBRST',
  'HARD',
  'PROV',
  'DC',
  'DV',
  'RSE',
  'OIL',
  'M',
  'APPLE',
  '3',
  'BAG',
  'STOK',
  'LT',
  'SWT',
  'PEANUT',
  'BUTTER',
  'AVO',
  'VERDE',
  'ROLLS',
  'BTS',
  'DRY',
  'BLON',
  'GALE',
  'TR',
  'HS',
  'FRM',
  '4',
  'BAGELS',
  'GV',
  'SLIDERS',
  'ACCESSORY',
  'CHEEZE',
  'IT',
  'RITZ',
  'RUFFLES',
  'GV',
  'HNY',
  'GRMS'],
 ['SW', 'HRO', 'FGHTR'],
 ['KTTL',
  'SEA',
  'SALT',
  'POT',
  'CHP',
  'BRAIDED',
  'BRIOCHE',
  'CHEF',
  'PLATE',
  'MEAL'],
 ['Woman',
  'Ham',
  'Cheese',
  'Ice',
  'Java',
  'Tea',
  'Mineral',
  'Water',
  'Black',
  '&',
  'White'],
 ['6', 'WING', 'PLATE', 'ASST', '27', 'CUTIE', 'CAR'],
 ['FF',
  'BS',
  'BREAST',
  'KS',
  'DICED',
  'TOM',
  'JACKORGSALSE',
  '18CT',
  'EGGS',
  'GRAPE',
  'TOMATO',
  'ECO',
  'HALF',
  'PAN',
  'GRND',
  'TURKEY',
  'CHPD',
  'ONION',
  'MONT',
  'JACK',
  '2#'],
 ['N',
  'YORK',
  'TX',
  'GRLC',
  'CHICKEN',
  'WINGS',
  'PICSWEET',
  'BLEND',
  'PICSWEET',
  'GREENS',
  'CHICKEN',
  'WINGS',
  'DIET',
  'LN',
  'GRND',
  'B',
  'PORK',
  'LOIN',
  'CHOP',
  'DRUMSTICKS',
  'EYE',
  'RND',
  'STK',
  'FP',
  'EYE',
  'RND',
  'STK',
  'FP',
  'BEEF',
  'FOR',
  'STEW',
  'PORK',
  '1',
  '2',
  'LOIN',
  'B',
  'BEST',
  'S',
  'STEAK',
  'BAR',
  'S',
  'MEAT',
  'FRNK',
  '0',
  'M',
  'HAM',
  'WINCO',
  'NOODLES',
  'TNDRBRD',
  'CHIX',
  'BR',
  'KRFT',
  'DELUXE',
  'MAC',
  'EGGO',
  'WAFFLE',
  'L',
  'D',
  'NUTTY',
  'BARS',
  'L',
  'D',
  'OATMEAL',
  'CRM',
  'LINKS',
  'MILD',
  'KEEB',
  'TOWNHOUSE',
  'TURKEY',
  'FRANK',
  'RESERS',
  'POT',
  'SLD',
  'DM',
  'SPAG',
  'SAUCE',
  'HUNTS',
  'MANWICH',
  'DM',
  'PNAPL',
  'CHNKY',
  'SUNBEAN',
  'BUNS',
  'WINCO',
  'SNDWCH',
  'WT',
  'WINCO',
  'HOMO',
  'MILK',
  'EGGS'],
 ['LAZENBY',
  'WORCESTER',
  'SAUCE',
  'MILKY',
  'BAR',
  'CHOC',
  'SMOKED',
  'VIENNAS',
  'PEALED',
  'PEACHES',
  'MEDITERRANEAN',
  'MIX',
  'SPAR',
  'COOKING',
  'OIL',
  'F',
  'L',
  'ENGLISH',
  'CUCUMB',
  'NESTLE',
  'AERO',
  'CADBURY',
  'DAIRY',
  'MI',
  'GRAPES',
  'MIXED',
  'TUB',
  'TASTIC',
  'RICE',
  'BLACK',
  'CAT',
  'SMOOTH',
  'CARRIER',
  'BAG',
  '24L',
  'BANANAS',
  'LOOSE'],
 ['PL',
  "TORTILLA'S",
  'CAGE',
  'FREE',
  'ALL',
  'WHIT',
  'BLACK',
  'BEANS',
  'Frozen',
  'Mangoes',
  '16o',
  'Whole',
  'Strawberries',
  'OG',
  'LF',
  'COTTAGE',
  'CHEE',
  'MAHI',
  'MAHI',
  'FILLETS',
  '$2',
  'off',
  '(1)',
  'WC',
  'Fill',
  'California',
  'Harvest',
  'PLUMS',
  'BLACK',
  'CV'],
 ['SW', 'FIGURES', 'TOOTHBRUSH', 'WOMEN', 'SLIPPE'],
 ['GIFT', 'CARD'],
 ['EQUATE',
  'LINER',
  'VFUS',
  'ENG',
  'POM',
  'DAWN',
  'ORIG',
  '50YD',
  'PKGTAPE',
  '50YD',
  'PKGTAPE',
  'LINT',
  'POLLER2'],
 ['DIABETES'],
 ['6', 'WING', 'PLATE', 'ASST', '27', 'CUTIE', 'CAR'],
 ['BANANAS',
  'BEVERAGE',
  'OS',
  'CRAN',
  'POM',
  'STRWBRY',
  'CC',
  'CAMPARI',
  'TOM',
  'KFT',
  'SINGLES',
  'HARD',
  'SALAMI',
  'AVOCADO',
  'PILLS',
  'WHITE',
  'SH',
  'NYLON',
  'COL',
  'HAND',
  'CLEANER',
  'INJECTR',
  'CLNR'],
 ['GV',
  'WATER',
  'GV',
  'WATER',
  'GREAT',
  'VALUE',
  'GREAT',
  'VALUE',
  'GAIN',
  'LFE',
  'GAIN',
  'GV',
  'VEG',
  'OIL',
  'SNICKER',
  'FS',
  'GDBR',
  'FS',
  '6PK',
  'MIXED',
  'CHOC',
  'CHERRIES',
  'GAIN',
  'HY',
  'PSTLEG',
  'PM',
  'BATTERIES',
  'GV',
  '20Z',
  'MINI',
  'CRNBRY',
  'SAUCE',
  'SPREADS',
  'EGGS',
  '6CT'],
 ['GRILL', 'COVER', 'FIBER', 'CHOICE', 'CELERY', 'HEART', 'RED', 'GRAPE']]

# %%
def extract_text_tesseract(image_path):
    try:
        image = Image.open(image_path)
        recognized_text = pytesseract.image_to_string(image)
        return recognized_text
    except Exception as e:
        return str(e), None

# %%
extract_text_tesseract(f'{path}/images/0.jpg')
# Out:
# 'WAL*MART\n\nALWAYS LOW PRICES.\n\nwoe\n\nSUPERCENTER\nOPEN 24 HOURS\nMANAGER . TBA\n(515 ) 986 - 1783\n$T# 5748 OP# 00000158 TE¥ 14 TRH 03178\nBANANAS 00000000401 1kF\n0.41 Ib @ 1 Ib /0.49 0.20 N\nFRAP 001200010451 F 5.48 N\nDISCOUNT GIVEN 0.57\n‘| SUBIQIA. = 8.11\n5.\ny CASH TEND 1100\nCHANGE DUE “5 "@g\n\n'

# %%
results = []
for i in range(len(valid_data)):
    image_path = f'{path}/images/{i}.jpg'

    start_time = time.time()
    recognized_text = extract_text_tesseract(image_path)
    end_time = time.time()
    processing_time = end_time - start_time
    
    results.append({
        "image_path": image_path,
        "ground_truth": valid_data[i],
        "recognized_text": recognized_text,
        "processing_time": processing_time,
    })

results_df = pd.DataFrame(results)
results_df
# Out:
#                                            image_path  \
# 0   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 1   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 2   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 3   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 4   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 5   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 6   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 7   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 8   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 9   C:\Users\gta76\.cache\kagglehub\datasets\train...
# 10  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 11  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 12  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 13  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 14  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 15  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 16  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 17  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 18  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 19  C:\Users\gta76\.cache\kagglehub\datasets\train...
#
#                                          ground_truth  \
# 0                                     [BANANAS, FRAP]
# 1   [R, CARROTS, SHREDDED, 10, OZ, R, CUCUMBERS, P...
# 2   [GV, OATMEAL, OT, 200Z, TUM, M, ATHLETICS, DEX...
# 3   [TATER, TOTS, HARD, PROV, DC, SNACK, BARS, HRI...
# 4                                    [SW, HRO, FGHTR]
# 5   [KTTL, SEA, SALT, POT, CHP, BRAIDED, BRIOCHE, ...
# 6   [Woman, Ham, Cheese, Ice, Java, Tea, Mineral, ...
# 7              [6, WING, PLATE, ASST, 27, CUTIE, CAR]
# 8   [FF, BS, BREAST, KS, DICED, TOM, JACKORGSALSE,...
# 9   [N, YORK, TX, GRLC, CHICKEN, WINGS, PICSWEET, ...
# 10  [LAZENBY, WORCESTER, SAUCE, MILKY, BAR, CHOC, ...
# 11  [PL, TORTILLA'S, CAGE, FREE, ALL, WHIT, BLACK,...
# 12           [SW, FIGURES, TOOTHBRUSH, WOMEN, SLIPPE]
# 13                                       [GIFT, CARD]
# 14  [EQUATE, LINER, VFUS, ENG, POM, DAWN, ORIG, 50...
# 15                                         [DIABETES]
# 16             [6, WING, PLATE, ASST, 27, CUTIE, CAR]
# 17  [BANANAS, BEVERAGE, OS, CRAN, POM, STRWBRY, CC...
# 18  [GV, WATER, GV, WATER, GREAT, VALUE, GREAT, VA...
# 19  [GRILL, COVER, FIBER, CHOICE, CELERY, HEART, R...
#
#                                       recognized_text  processing_time
# 0   WAL*MART\n\nALWAYS LOW PRICES.\n\nwoe\n\nSUPER...         1.346586
# 1   TRADER JOE'S\n\n2001 Greenville Ave\nDallas TX...         0.771985
# 2   Give us feedback @ survey.walmart .com\nThank ...         0.653001
# 3   See back of up chance\nto win $1000 Th gsNoTVE...         0.716002
# 4   Walmart ><\n\n( 712 ) 366 - 3326\nMANAGER DONA...         0.533998
# 5   WHOLE FOODs\n\nMARKET\n\nSunnyvale SVL 408-419...         3.096002
# 6   MOMI & TOY’S\n\nCREPERIE\n\nLippo Mall K\nKema...         0.983001
# 7   See back of receipt for your chance\nto win $1...         0.802997
# 8   Thornton #629\n16375 N. Washington St.\nThornt...         0.529999
# 9   Yolancta\nashi er fi\n\n99/08/14\n\nN/yoRK\n\n...         0.709002
# 10            Thank\n\nYou\n\nTAX INVOIL\nT\n\nCE\n\n         0.328029
# 11  WHOLE\nFOODS\n\nSHARON RD.\n\nPL TORTILLA’S\nC...         0.509051
# 12  WAL*MART\n\nSave money. Live better.\n\nWE SEL...         0.646961
# 13  TD A ASWOYBKCH\n\nWalmart >)<\n\nSave money. L...         0.589000
# 14  See back of receipt for your chance\nto win $1...         3.964951
# 15  Walmart 7 =\n\nSave money: Live better:\n\nail...         0.665990
# 16  See back of receipt for your chance\nto win $1...         0.743984
# 17  See iced Bho receipt for your chance\nto win #...         0.763993
# 18  Give’ u\ndae\n\nThanked eedback\nak Your 1D 4 ...         1.021012
# 19  Give us feedback @\nThank’ yout TD #: 7OOR III...         0.635010

# %%
def normalize_text(text: str) -> str:
    return text.lower().translate(str.maketrans('', '', string.punctuation))

def calculate_accuracy(recognized: List[str], valid: List[str]) -> dict:
    recognized_set = {normalize_text(word) for word in recognized}
    valid_set = {normalize_text(word) for word in valid}
    
    true_positives = len(recognized_set & valid_set)
    false_positives = len(recognized_set - valid_set)
    false_negatives = len(valid_set - recognized_set)
    
    precision = true_positives / (true_positives + false_positives) if recognized_set else 0
    recall = true_positives / (true_positives + false_negatives) if valid_set else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0
    
    return {
        "precision": precision * 100,
        "recall": recall * 100,
        "f1_score": f1_score * 100,
        "accuracy": (true_positives / len(valid)) * 100 if valid else 0
    }

for i in range(len(valid_data)):
    metrics = calculate_accuracy(results_df['recognized_text'][i].split(), valid_data[i])
    print(f'Image {i}:')
    print(f"  Precision: {metrics['precision']:.2f}%")
    print(f"  Recall: {metrics['recall']:.2f}%")
    print(f"  F1-Score: {metrics['f1_score']:.2f}%")
    print(f"  Accuracy: {metrics['accuracy']:.2f}%")
    print(f"  Time: {end_time - start_time}")
    print('-' * 30)
# Out:
# Image 0:
#   Precision: 3.92%
#   Recall: 100.00%
#   F1-Score: 7.55%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 1:
#   Precision: 41.67%
#   Recall: 76.27%
#   F1-Score: 53.89%
#   Accuracy: 60.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 2:
#   Precision: 7.21%
#   Recall: 88.89%
#   F1-Score: 13.33%
#   Accuracy: 88.89%
#   Time: 0.6350102424621582
# ------------------------------
# Image 3:
#   Precision: 12.05%
#   Recall: 18.87%
#   F1-Score: 14.71%
#   Accuracy: 14.71%
#   Time: 0.6350102424621582
# ------------------------------
# Image 4:
#   Precision: 3.41%
#   Recall: 100.00%
#   F1-Score: 6.59%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 5:
#   Precision: 7.09%
#   Recall: 90.00%
#   F1-Score: 13.14%
#   Accuracy: 90.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 6:
#   Precision: 14.47%
#   Recall: 100.00%
#   F1-Score: 25.29%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 7:
#   Precision: 5.69%
#   Recall: 100.00%
#   F1-Score: 10.77%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 8:
#   Precision: 25.00%
#   Recall: 95.24%
#   F1-Score: 39.60%
#   Accuracy: 95.24%
#   Time: 0.6350102424621582
# ------------------------------
# Image 9:
#   Precision: 33.65%
#   Recall: 47.30%
#   F1-Score: 39.33%
#   Accuracy: 38.89%
#   Time: 0.6350102424621582
# ------------------------------
# Image 10:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 11:
#   Precision: 38.81%
#   Recall: 92.86%
#   F1-Score: 54.74%
#   Accuracy: 86.67%
#   Time: 0.6350102424621582
# ------------------------------
# Image 12:
#   Precision: 6.33%
#   Recall: 100.00%
#   F1-Score: 11.90%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 13:
#   Precision: 1.19%
#   Recall: 50.00%
#   F1-Score: 2.33%
#   Accuracy: 50.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 14:
#   Precision: 8.42%
#   Recall: 72.73%
#   F1-Score: 15.09%
#   Accuracy: 61.54%
#   Time: 0.6350102424621582
# ------------------------------
# Image 15:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 16:
#   Precision: 5.69%
#   Recall: 100.00%
#   F1-Score: 10.77%
#   Accuracy: 100.00%
#   Time: 0.6350102424621582
# ------------------------------
# Image 17:
#   Precision: 8.91%
#   Recall: 39.13%
#   F1-Score: 14.52%
#   Accuracy: 39.13%
#   Time: 0.6350102424621582
# ------------------------------
# Image 18:
#   Precision: 3.73%
#   Recall: 23.08%
#   F1-Score: 6.42%
#   Accuracy: 17.14%
#   Time: 0.6350102424621582
# ------------------------------
# Image 19:
#   Precision: 4.60%
#   Recall: 50.00%
#   F1-Score: 8.42%
#   Accuracy: 50.00%
#   Time: 0.6350102424621582
# ------------------------------
