# %%
# !pip install paddlepaddle
# !pip install paddleocr
# Out:
# Requirement already satisfied: paddlepaddle in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (2.6.2)
# Requirement already satisfied: httpx in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (11.0.0)
# Requirement already satisfied: decorator in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: astor in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf<=3.20.2,>=3.1.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddlepaddle) (3.20.2)
# Requirement already satisfied: anyio in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from httpx->paddlepaddle) (4.7.0)
# Requirement already satisfied: certifi in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from httpx->paddlepaddle) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from httpx->paddlepaddle) (1.0.7)
# Requirement already satisfied: idna in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from httpx->paddlepaddle) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from anyio->httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from anyio->httpx->paddlepaddle) (4.12.2)
# Requirement already satisfied: paddleocr in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (2.9.1)
# Requirement already satisfied: shapely in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (0.25.0)
# Requirement already satisfied: imgaug in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (1.3.0.post6)
# Requirement already satisfied: lmdb in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (4.67.1)
# Requirement already satisfied: numpy<2.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (3.11.0)
# Requirement already satisfied: opencv-python in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: Pillow in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (11.0.0)
# Requirement already satisfied: pyyaml in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: python-docx in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (4.55.3)
# Requirement already satisfied: fire>=0.3.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (0.7.0)
# Requirement already satisfied: requests in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: albumentations==1.4.10 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (1.4.10)
# Requirement already satisfied: albucore==0.0.13 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from paddleocr) (0.0.13)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albucore==0.0.13->paddleocr) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albucore==0.0.13->paddleocr) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albucore==0.0.13->paddleocr) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.6.0)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from albumentations==1.4.10->paddleocr) (2.10.4)
# Requirement already satisfied: termcolor in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-image->paddleocr) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-image->paddleocr) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-image->paddleocr) (2024.12.12)
# Requirement already satisfied: packaging>=21 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-image->paddleocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: six in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from imgaug->paddleocr) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from imgaug->paddleocr) (3.10.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from python-docx->paddleocr) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from requests->paddleocr) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from requests->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from requests->paddleocr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from requests->paddleocr) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from tqdm->paddleocr) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (2.27.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from matplotlib->imgaug->paddleocr) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gta76\desktop\project\ml-project\.venv\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)

# %%
from paddleocr import PaddleOCR
import time
import pandas as pd
import kagglehub
from typing import List
import string

path = kagglehub.dataset_download("trainingdatapro/ocr-receipts-text-detection")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en')
# Out:
# [2024/12/21 16:38:44] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\gta76/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\gta76/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\gta76\\Desktop\\project\\ml-project\\.venv\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\gta76/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
valid_data = [
    ['BANANAS', 'FRAP'],
    ['R-CARROTS SHREDDED 10 OZ', 'R-CUCUMBERS PERSIAN 1 LB', 'TOMATOES CRUSHED NO SALT', 'TOMATOES WHOLE NO SALT W/BASIL', 
     'ORGANIC OLD FASHIONED OATMEAL', 'MINI-PEARL TOMATOES..', 'PKG SHREDDED MOZZARELLA LITE T', 'EGGS 1 DOZ ORGANIC BROWN.', 
     'BEANS GARBANZO', 'SPROUTED CA STYLE', 'A-AVOCADOS HASS BAG 4CT', 'A-APPLE BAG JAZZ 2 LB', 'A-PEPPER BELL EACH XL RED', 
     'GROCERY NON TAXABLE', 'BANANAS ORGANIC', 'CREAMY SALTED PEANUT BUTTER', 'WHL WHT PITA BREAD', 'GROCERY NON TAXABLE'],
    ['GV OATMEAL', 'OT 200Z TUM', 'M ATHLETICS', 'DEXAS 15X20'],
    ['TATER TOTS', 'HARD/PROV/DC', 'SNACK BARS', 'HRI CL CHS', 'HRI CL CHS', 'HRI CL CHS', 'HRI 12 U SG', 'HRI CL PEP', 'EARBUDS',
      'SC BCN CHDDR', 'ABF THINBRST', 'ABF THINBRST', 'HARD/PROV/DC', 'DV RSE OIL M', 'APPLE 3 BAG', 'STOK LT SWT', 'PEANUT BUTTER',
      'AVO VERDE', 'ROLLS', 'BTS DRY BLON', 'GALE', 'TR HS FRM 4', 'BAGELS', 'GV SLIDERS', 'ACCESSORY', 'CHEEZE IT', 'RITZ', 'RUFFLES', 'GV HNY GRMS'],
    ['SW HRO FGHTR'],
    ['KTTL SEA SALT POT CHP', 'BRAIDED BRIOCHE', 'CHEF PLATE MEAL'],
    ['Woman', 'Ham Cheese', 'Ice Java Tea', 'Mineral Water', 'Black & White'],
    ['6 WING PLATE', 'ASST 27', 'CUTIE CAR'],
    ['FF BS BREAST', 'KS DICED TOM', 'JACKORGSALSE', '18CT EGGS', 'GRAPE TOMATO', 'ECO HALF PAN', 'GRND TURKEY', 'CHPD ONION', 'MONT JACK 2#'],
    ['N/YORK TX GRLC', 'CHICKEN WINGS', 'PICSWEET BLEND', 'PICSWEET GREENS', 'CHICKEN WINGS', 'DIET LN GRND B', 'PORK LOIN CHOP', 'DRUMSTICKS',
     'EYE RND STK FP', 'EYE RND STK FP', 'BEEF FOR STEW', 'PORK 1/2 LOIN', 'B/BEST S STEAK', 'BAR S MEAT FRNK', '0/M HAM', 'WINCO NOODLES', 'TNDRBRD CHIX BR'
     'KRFT DELUXE MAC', 'EGGO WAFFLE', 'L/D NUTTY BARS', 'L\D OATMEAL CRM', 'LINKS MILD', 'KEEB TOWNHOUSE', 'TURKEY FRANK', 'RESERS POT SLD', 'DM SPAG SAUCE',
     'HUNTS MANWICH', 'DM PNAPL CHNKY', 'SUNBEAN BUNS', 'WINCO SNDWCH WT', 'WINCO HOMO MILK', 'EGGS'],
    ['LAZENBY WORCESTER SAUCE', 'MILKY BAR CHOC', 'SMOKED VIENNAS', 'PEALED PEACHES', 'MEDITERRANEAN MIX', 'SPAR COOKING OIL',
     'F/L ENGLISH CUCUMB', 'NESTLE AERO', 'CADBURY DAIRY MI', 'GRAPES MIXED TUB', 'TASTIC RICE', 'BLACK CAT SMOOTH', 'CARRIER BAG 24L', 'BANANAS LOOSE'],
    ["PL TORTILLA'S", 'CAGE FREE ALL WHIT', 'BLACK BEANS', 'Frozen Mangoes 16o', 'Whole Strawberries', 'OG LF COTTAGE CHEE', 'MAHI MAHI FILLETS', '$2 off (1) WC Fill',
     'California Harvest', 'PLUMS BLACK CV'],
    ['SW FIGURES', 'TOOTHBRUSH', 'WOMEN SLIPPE'],
    ['GIFT CARD'],
    ['EQUATE LINER', 'VFUS ENG POM', 'DAWN ORIG', '50YD PKGTAPE', '50YD PKGTAPE', 'LINT POLLER2'],
    ['DIABETES'],
    ['6 WING PLATE', 'ASST 27', 'CUTIE CAR'],
    ['BANANAS', 'BEVERAGE', 'OS CRAN POM', 'STRWBRY CC', 'CAMPARI TOM', 'KFT SINGLES', 'HARD SALAMI', 'AVOCADO', 'PILLS WHITE', 'SH NYLON COL', 'HAND CLEANER', 'INJECTR CLNR'],
    ['GV WATER', 'GV WATER', 'GREAT VALUE', 'GREAT VALUE', 'GAIN LFE', 'GAIN', 'GV VEG OIL', 'SNICKER FS', 'GDBR FS 6PK', 'MIXED CHOC', 'CHERRIES', 'GAIN', 'HY PSTLEG PM',
     'BATTERIES', 'GV 20Z MINI', 'CRNBRY SAUCE', 'SPREADS', 'EGGS 6CT'],
    ['GRILL COVER', 'FIBER CHOICE', 'CELERY HEART', 'RED GRAPE'],
]

# %%
def extract_text_paddle(image_path):
    try:
        result = ocr.ocr(image_path, cls=True)
        texts = []
        for line in result[0]:
            texts.append(line[1][0])

        return " ".join(texts)
    except Exception as e:
        return str(e), None

# %%
# Out:
# [2024/12/21 16:38:51] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.537996768951416
# [2024/12/21 16:38:51] ppocr DEBUG: cls num  : 36, elapsed : 0.13299965858459473
# [2024/12/21 16:38:54] ppocr DEBUG: rec_res num  : 36, elapsed : 2.9640016555786133
# 'WAL*MART ALWAYS LOW PRICES. Always SUPERCENTER OPEN 24 HOURS MANAGERTBA 515986-1783 BANANAS 000000004011KF 0.411b 11b /0.49 0.20N FRAP 001200010451F 5.48N DISCOUNT GIVEN 0.57 SUBTOTAL 5.11 TOTAL 5.11 CASHTEND 11.00 CHANGE DUE 5.89 #ITEMS SOLD2 TC#.56798348648578282003 THANK YOU FOR SHOPPING WITH US NATHANIEL BUSH Shop at Walmart & Get Your Back to School List for Less 08/20/10 13:12:01'

# %%
results = []
for i in range(int(len(valid_data) / 2)):
    image_path = f'{path}/images/{i}.jpg'

    start_time = time.time()
    recognized_text = extract_text_paddle(image_path)
    end_time = time.time()
    processing_time = end_time - start_time
    
    results.append({
        "image_path": image_path,
        "ground_truth": valid_data[i],
        "recognized_text": recognized_text,
        "processing_time": processing_time,
    })

results_df = pd.DataFrame(results)
results_df
# Out:
# [2024/12/21 16:40:29] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.5599985122680664
# [2024/12/21 16:40:29] ppocr DEBUG: cls num  : 36, elapsed : 0.10000371932983398
# [2024/12/21 16:40:31] ppocr DEBUG: rec_res num  : 36, elapsed : 2.174032688140869
# [2024/12/21 16:40:32] ppocr DEBUG: dt_boxes num : 58, elapsed : 0.5693895816802979
# [2024/12/21 16:40:32] ppocr DEBUG: cls num  : 58, elapsed : 0.235001802444458
# [2024/12/21 16:40:35] ppocr DEBUG: rec_res num  : 58, elapsed : 3.167999029159546
# [2024/12/21 16:40:36] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.43599915504455566
# [2024/12/21 16:40:36] ppocr DEBUG: cls num  : 53, elapsed : 0.23200154304504395
# [2024/12/21 16:40:40] ppocr DEBUG: rec_res num  : 53, elapsed : 3.686998128890991
# [2024/12/21 16:40:40] ppocr DEBUG: dt_boxes num : 119, elapsed : 0.6450381278991699
# [2024/12/21 16:40:41] ppocr DEBUG: cls num  : 119, elapsed : 0.1939983367919922
# [2024/12/21 16:40:46] ppocr DEBUG: rec_res num  : 119, elapsed : 5.41015625
# [2024/12/21 16:40:46] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.40003156661987305
# [2024/12/21 16:40:47] ppocr DEBUG: cls num  : 39, elapsed : 0.15499591827392578
# [2024/12/21 16:40:49] ppocr DEBUG: rec_res num  : 39, elapsed : 2.592930555343628
# [2024/12/21 16:40:50] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.5159990787506104
# [2024/12/21 16:40:50] ppocr DEBUG: cls num  : 43, elapsed : 0.16099834442138672
# [2024/12/21 16:40:54] ppocr DEBUG: rec_res num  : 43, elapsed : 4.394997596740723
# [2024/12/21 16:40:55] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.675999641418457
# [2024/12/21 16:40:55] ppocr DEBUG: cls num  : 37, elapsed : 0.12099981307983398
# [2024/12/21 16:40:58] ppocr DEBUG: rec_res num  : 37, elapsed : 2.4110004901885986
# [2024/12/21 16:40:58] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.37399959564208984
# [2024/12/21 16:40:58] ppocr DEBUG: cls num  : 54, elapsed : 0.09600019454956055
# [2024/12/21 16:41:01] ppocr DEBUG: rec_res num  : 54, elapsed : 3.188999652862549
# [2024/12/21 16:41:02] ppocr DEBUG: dt_boxes num : 56, elapsed : 0.6569998264312744
# [2024/12/21 16:41:02] ppocr DEBUG: cls num  : 56, elapsed : 0.21300005912780762
# [2024/12/21 16:41:05] ppocr DEBUG: rec_res num  : 56, elapsed : 2.959001064300537
# [2024/12/21 16:41:06] ppocr DEBUG: dt_boxes num : 91, elapsed : 0.5289995670318604
# [2024/12/21 16:41:06] ppocr DEBUG: cls num  : 91, elapsed : 0.21199727058410645
# [2024/12/21 16:41:10] ppocr DEBUG: rec_res num  : 91, elapsed : 3.9189984798431396
#                                           image_path  \
# 0  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 1  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 2  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 3  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 4  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 5  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 6  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 7  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 8  C:\Users\gta76\.cache\kagglehub\datasets\train...
# 9  C:\Users\gta76\.cache\kagglehub\datasets\train...
#
#                                         ground_truth  \
# 0                                    [BANANAS, FRAP]
# 1  [R-CARROTS SHREDDED 10 OZ, R-CUCUMBERS PERSIAN...
# 2  [GV OATMEAL, OT 200Z TUM, M ATHLETICS, DEXAS 1...
# 3  [TATER TOTS, HARD/PROV/DC, SNACK BARS, HRI CL ...
# 4                                     [SW HRO FGHTR]
# 5  [KTTL SEA SALT POT CHP, BRAIDED BRIOCHE, CHEF ...
# 6  [Woman, Ham Cheese, Ice Java Tea, Mineral Wate...
# 7                 [6 WING PLATE, ASST 27, CUTIE CAR]
# 8  [FF BS BREAST, KS DICED TOM, JACKORGSALSE, 18C...
# 9  [N/YORK TX GRLC, CHICKEN WINGS, PICSWEET BLEND...
#
#                                      recognized_text  processing_time
# 0  WAL*MART ALWAYS LOW PRICES. Always SUPERCENTER...         2.869035
# 1  TRADER JOE'S 2001 Greenvi1le Ave Dallas TX 752...         4.005390
# 2  Give us feedback @ survey.walmart.com Thank yo...         4.375000
# 3  Walmart' 882S.STATE ROAD 135 GREENWOOD IN 4614...         6.280192
# 4  Walmart Save money. Live better. 712366-3326 M...         3.164963
# 5  WHOLE FOODS MARKET Sunnyvale SVL 408-419-1290 ...         5.370081
# 6  MOMICTOY'S CREPERIE Lippo Ma11Kemang, Kemang V...         3.275005
# 7  See back of receipt for your chance to win $10...         3.686998
# 8  COSTCO WHOLESALE Thornton #629 16375 N. Washin...         3.853001
# 9  WinCo FOODS www.wincofoods.com Store #0124 09/...         4.687999

# %%
def normalize_text(text: str) -> str:
    return text.lower().translate(str.maketrans('', '', string.punctuation))

def calculate_accuracy(recognized: List[str], valid: List[str]) -> dict:
    recognized_set = {normalize_text(word) for word in recognized}
    valid_set = {normalize_text(word) for word in valid}
    
    true_positives = len(recognized_set & valid_set)
    false_positives = len(recognized_set - valid_set)
    false_negatives = len(valid_set - recognized_set)
    
    precision = true_positives / (true_positives + false_positives) if recognized_set else 0
    recall = true_positives / (true_positives + false_negatives) if valid_set else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0
    
    return {
        "precision": precision * 100,
        "recall": recall * 100,
        "f1_score": f1_score * 100,
        "accuracy": (true_positives / len(valid)) * 100 if valid else 0
    }

for i in range(int(len(valid_data) / 2)):
    metrics = calculate_accuracy(results_df['recognized_text'][i].split(), valid_data[i])
    print(f'Image {i}:')
    print(f"  Precision: {metrics['precision']:.2f}%")
    print(f"  Recall: {metrics['recall']:.2f}%")
    print(f"  F1-Score: {metrics['f1_score']:.2f}%")
    print(f"  Accuracy: {metrics['accuracy']:.2f}%")
    print(f"  Time: {end_time - start_time}")
    print('-' * 30)
# Out:
# Image 0:
#   Precision: 3.77%
#   Recall: 100.00%
#   F1-Score: 7.27%
#   Accuracy: 100.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 1:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 2:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 3:
#   Precision: 5.15%
#   Recall: 28.00%
#   F1-Score: 8.70%
#   Accuracy: 24.14%
#   Time: 4.687998533248901
# ------------------------------
# Image 4:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 5:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 6:
#   Precision: 1.82%
#   Recall: 20.00%
#   F1-Score: 3.33%
#   Accuracy: 20.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 7:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 8:
#   Precision: 0.00%
#   Recall: 0.00%
#   F1-Score: 0.00%
#   Accuracy: 0.00%
#   Time: 4.687998533248901
# ------------------------------
# Image 9:
#   Precision: 1.54%
#   Recall: 6.90%
#   F1-Score: 2.52%
#   Accuracy: 6.45%
#   Time: 4.687998533248901
# ------------------------------
